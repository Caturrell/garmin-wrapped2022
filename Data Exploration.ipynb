# %% [markdown]
# # Garmin Data Exploration and Wrangling

# %% [markdown]
# ### Preliminary Work
#
# Firstly, we import the required packages then import the dataset and view the first few rows.

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Now, read the csv file and view the head of the data.

# %%
garmin = pd.read_csv("activities.csv")
garmin.head()
# Out:
#      Activity Type                 Date  Favorite  \
# 0           Hiking  2022-12-21 10:40:56     False
# 1  Mountain Biking  2022-12-14 09:17:47     False
# 2          Running  2022-12-12 14:38:08     False
# 3          Running  2022-12-07 15:48:15     False
# 4          Running  2022-12-05 12:38:49     False
#
#                             Title Distance Calories      Time  Avg HR  Max HR  \
# 0  Monte Castello di Vibio Hiking     6.30      472  01:32:43      99     122
# 1     Teignbridge Mountain Biking    12.81      916  01:08:34     153     188
# 2                  Exeter Running     9.73      747  01:03:58     138     156
# 3                  Exeter Running     5.66      444  00:41:19     127     151
# 4                  Exeter Running     5.11      397  00:36:00     129     150
#
#   Aerobic TE  ...  Min Temp  Surface Interval Decompression Best Lap Time  \
# 0        1.0  ...      21.0              0:00            No    00:03.93.8
# 1        4.2  ...      15.0              0:00            No    14:19.80.2
# 2        3.2  ...       9.0              0:00            No    04:43.60.8
# 3        2.9  ...      15.0              0:00            No    05:35.67.4
# 4        2.7  ...      18.0              0:00            No    00:49.93.8
#
#   Number of Laps Max Temp  Moving Time  Elapsed Time  Min Elevation  \
# 0              3      0.0     01:22:39      01:32:43            -59
# 1              3      0.0     01:00:25      01:08:34            158
# 2             10      0.0     01:02:58      01:03:58              6
# 3              6      0.0     00:34:22      00:41:19              8
# 4              6      0.0     00:33:52      00:36:00              4
#
#    Max Elevation
# 0            -27
# 1            267
# 2             40
# 3             23
# 4             17
#
# [5 rows x 43 columns]

# %% [markdown]
# Let's view the general info of the dataset

# %%
print("Number of columns in dataset:", len(garmin))
print()
print(garmin.info())
# Out:
# Number of columns in dataset: 160
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 43 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   activity            160 non-null    object
#  1   date                160 non-null    object
#  2   fav                 160 non-null    bool
#  3   title               160 non-null    object
#  4   distance            160 non-null    object
#  5   calories            160 non-null    object
#  6   time                160 non-null    object
#  7   avg_hr              160 non-null    int64
#  8   max_hr              160 non-null    int64
#  9   aerobic_te          160 non-null    object
#  10  avg_run_cadence     160 non-null    int64
#  11  max_run_cadence     160 non-null    int64
#  12  avg_pace            160 non-null    object
#  13  best_pace           160 non-null    object
#  14  total_ascent        160 non-null    object
#  15  total_descent       160 non-null    object
#  16  avg_stride          160 non-null    float64
#  17  avg_vert_ratio      160 non-null    float64
#  18  avg_vert_osc        160 non-null    float64
#  19  avg_ground_contact  160 non-null    int64
#  20  avg_run_cadence1    160 non-null    int64
#  21  max_run_cadence1    160 non-null    int64
#  22  training_stress     160 non-null    float64
#  23  max_avg_power20     160 non-null    object
#  24  avg_power           160 non-null    int64
#  25  max_power           160 non-null    int64
#  26  grit                160 non-null    float64
#  27  flow                160 non-null    float64
#  28  total_strokes       160 non-null    object
#  29  avg_swolf           160 non-null    int64
#  30  avg_stroke_rate     160 non-null    int64
#  31  total_reps          160 non-null    int64
#  32  dive_time           160 non-null    object
#  33  min_temp            160 non-null    float64
#  34  surface_interval    160 non-null    object
#  35  decomp              160 non-null    object
#  36  best_lap            160 non-null    object
#  37  number_laps         160 non-null    int64
#  38  max_temp            160 non-null    float64
#  39  moving_time         160 non-null    object
#  40  elapsed_time        160 non-null    object
#  41  min_elav            160 non-null    object
#  42  max_elav            160 non-null    object
# dtypes: bool(1), float64(8), int64(13), object(21)
# memory usage: 52.8+ KB
# None

# %% [markdown]
# ### Change Column Names
#
# View column names and change them to suitable, easy to manage names.

# %%
garmin.columns = ['activity', 'date', 'fav', 'title', 'distance', 'calories', 
                  'time', 'avg_hr', 'max_hr', 'aerobic_te', 'avg_run_cadence',
                  'max_run_cadence', 'avg_pace', 'best_pace', 'total_ascent',
                  'total_descent', 'avg_stride', 'avg_vert_ratio', 
                  'avg_vert_osc', 'avg_ground_contact',
                  'avg_run_cadence1', 'max_run_cadence1', 'training_stress', 'max_avg_power20',
                  'avg_power', 'max_power', 'grit', 'flow', 'total_strokes', 'avg_swolf',
                  'avg_stroke_rate', 'total_reps', 'dive_time', 'min_temp',
                  'surface_interval', 'decomp', 'best_lap', 'number_laps',
                  'max_temp', 'moving_time', 'elapsed_time', 'min_elav', 'max_elav' ]
garmin.columns
# Out:
# Index(['activity', 'date', 'fav', 'title', 'distance', 'calories', 'time',
#        'avg_hr', 'max_hr', 'aerobic_te', 'avg_run_cadence', 'max_run_cadence',
#        'avg_pace', 'best_pace', 'total_ascent', 'total_descent', 'avg_stride',
#        'avg_vert_ratio', 'avg_vert_osc', 'avg_ground_contact',
#        'avg_run_cadence1', 'max_run_cadence1', 'training_stress',
#        'max_avg_power20', 'avg_power', 'max_power', 'grit', 'flow',
#        'total_strokes', 'avg_swolf', 'avg_stroke_rate', 'total_reps',
#        'dive_time', 'min_temp', 'surface_interval', 'decomp', 'best_lap',
#        'number_laps', 'max_temp', 'moving_time', 'elapsed_time', 'min_elav',
#        'max_elav'],
#       dtype='object')

# %%
garmin.head()
garmin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 43 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   activity            160 non-null    object
#  1   date                160 non-null    object
#  2   fav                 160 non-null    bool
#  3   title               160 non-null    object
#  4   distance            160 non-null    object
#  5   calories            160 non-null    object
#  6   time                160 non-null    object
#  7   avg_hr              160 non-null    int64
#  8   max_hr              160 non-null    int64
#  9   aerobic_te          160 non-null    object
#  10  avg_run_cadence     160 non-null    int64
#  11  max_run_cadence     160 non-null    int64
#  12  avg_pace            160 non-null    object
#  13  best_pace           160 non-null    object
#  14  total_ascent        160 non-null    object
#  15  total_descent       160 non-null    object
#  16  avg_stride          160 non-null    float64
#  17  avg_vert_ratio      160 non-null    float64
#  18  avg_vert_osc        160 non-null    float64
#  19  avg_ground_contact  160 non-null    int64
#  20  avg_run_cadence1    160 non-null    int64
#  21  max_run_cadence1    160 non-null    int64
#  22  training_stress     160 non-null    float64
#  23  max_avg_power20     160 non-null    object
#  24  avg_power           160 non-null    int64
#  25  max_power           160 non-null    int64
#  26  grit                160 non-null    float64
#  27  flow                160 non-null    float64
#  28  total_strokes       160 non-null    object
#  29  avg_swolf           160 non-null    int64
#  30  avg_stroke_rate     160 non-null    int64
#  31  total_reps          160 non-null    int64
#  32  dive_time           160 non-null    object
#  33  min_temp            160 non-null    float64
#  34  surface_interval    160 non-null    object
#  35  decomp              160 non-null    object
#  36  best_lap            160 non-null    object
#  37  number_laps         160 non-null    int64
#  38  max_temp            160 non-null    float64
#  39  moving_time         160 non-null    object
#  40  elapsed_time        160 non-null    object
#  41  min_elav            160 non-null    object
#  42  max_elav            160 non-null    object
# dtypes: bool(1), float64(8), int64(13), object(21)
# memory usage: 52.8+ KB

# %% [markdown]
# ### Create 2022 Dataframe
#
# Convert date column to datetime type and create sub-df with only 2022 activites.

# %%
garmin["date"] = pd.to_datetime(garmin["date"])
#garmin.dtypes # Check each column type

# %%
garmin["year"] = garmin["date"].dt.year
garmin22 = garmin[garmin["year"] == 2022]
garmin22.head()
# Out:
#           activity                date    fav                           title  \
# 0           Hiking 2022-12-21 10:40:56  False  Monte Castello di Vibio Hiking
# 1  Mountain Biking 2022-12-14 09:17:47  False     Teignbridge Mountain Biking
# 2          Running 2022-12-12 14:38:08  False                  Exeter Running
# 3          Running 2022-12-07 15:48:15  False                  Exeter Running
# 4          Running 2022-12-05 12:38:49  False                  Exeter Running
#
#   distance calories      time  avg_hr  max_hr aerobic_te  ...  \
# 0     6.30      472  01:32:43      99     122        1.0  ...
# 1    12.81      916  01:08:34     153     188        4.2  ...
# 2     9.73      747  01:03:58     138     156        3.2  ...
# 3     5.66      444  00:41:19     127     151        2.9  ...
# 4     5.11      397  00:36:00     129     150        2.7  ...
#
#    surface_interval  decomp    best_lap number_laps max_temp moving_time  \
# 0              0:00      No  00:03.93.8           3      0.0    01:22:39
# 1              0:00      No  14:19.80.2           3      0.0    01:00:25
# 2              0:00      No  04:43.60.8          10      0.0    01:02:58
# 3              0:00      No  05:35.67.4           6      0.0    00:34:22
# 4              0:00      No  00:49.93.8           6      0.0    00:33:52
#
#    elapsed_time  min_elav  max_elav  year
# 0      01:32:43       -59       -27  2022
# 1      01:08:34       158       267  2022
# 2      01:03:58         6        40  2022
# 3      00:41:19         8        23  2022
# 4      00:36:00         4        17  2022
#
# [5 rows x 44 columns]

# %% [markdown]
# ### Obtain Counts of Activities

# %%
print("Number of activites in 2022:", garmin22.count()[0])
garmin22["activity"].value_counts()
# Out:
# Number of activites in 2022: 149
# Running                       51
# Pool Swimming                 38
# Hiking                        13
# Mountain Biking               11
# Indoor Cycling                10
# Treadmill Running              7
# Resort Skiing/Snowboarding     7
# Cardio                         6
# Road Cycling                   5
# Cycling                        1
# Name: activity, dtype: int64
